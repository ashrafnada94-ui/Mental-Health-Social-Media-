# %%
import pandas as pd
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\User\Desktop\data\social media&mental health\social_media_mental_health.csv")

# %%
df.head()
# Out:
#       User_ID  Age  Gender      User_Archetype Primary_Platform  \
# 0  U-b23639d2   18    Male     Hyper-Connected        Twitter/X
# 1  U-e7778765   20    Male  Digital Minimalist           TikTok
# 2  U-76749892   18  Female  Digital Minimalist         Snapchat
# 3  U-dcbbd7f9   18  Female     Hyper-Connected         Snapchat
# 4  U-9e1ba278   18    Male     Hyper-Connected         LinkedIn
#
#    Daily_Screen_Time_Hours Dominant_Content_Type Activity_Type  \
# 0                     8.50                Gaming        Active
# 1                     0.50                Gaming        Active
# 2                     0.91                Gaming        Active
# 3                     7.43                Gaming        Active
# 4                     4.94  Entertainment/Comedy        Active
#
#    Late_Night_Usage  Social_Comparison_Trigger  Sleep_Duration_Hours  \
# 0                 0                          0                   3.9
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                      0
# Age                          0
# Gender                       0
# User_Archetype               0
# Primary_Platform             0
# Daily_Screen_Time_Hours      0
# Dominant_Content_Type        0
# Activity_Type                0
# Late_Night_Usage             0
# Social_Comparison_Trigger    0
# Sleep_Duration_Hours         0
# GAD_7_Score                  0
# GAD_7_Severity               0
# PHQ_9_Score                  0
# PHQ_9_Severity               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    8000 non-null   object
#  1   Age                        8000 non-null   int64
#  2   Gender                     8000 non-null   object
#  3   User_Archetype             8000 non-null   object
#  4   Primary_Platform           8000 non-null   object
#  5   Daily_Screen_Time_Hours    8000 non-null   float64
#  6   Dominant_Content_Type      8000 non-null   object
#  7   Activity_Type              8000 non-null   object
#  8   Late_Night_Usage           8000 non-null   int64
#  9   Social_Comparison_Trigger  8000 non-null   int64
#  10  Sleep_Duration_Hours       8000 non-null   float64
#  11  GAD_7_Score                8000 non-null   int64
#  12  GAD_7_Severity             8000 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age  Daily_Screen_Time_Hours  Late_Night_Usage  \
# count  8000.000000              8000.000000       8000.000000
# mean     19.057875                 4.277210          0.379375
# std       1.117892                 2.310486          0.485262
# min      18.000000                 0.500000          0.000000
# 25%      18.000000                 2.420000          0.000000
# 50%      19.000000                 4.270000          0.000000
# 75%      20.000000                 6.050000          1.000000
# max      22.000000                11.310000          1.000000
#
#        Social_Comparison_Trigger  Sleep_Duration_Hours  GAD_7_Score  \
# count                8000.000000           8000.000000  8000.000000
# mean                    0.103125              5.803237     7.354250
# std                     0.304141              1.344054     4.633108
# min                     0.000000              3.000000     0.000000
# ...

# %%
df.groupby('Dominant_Content_Type')['GAD_7_Severity'].value_counts(ascending = False)
# Out:
# Dominant_Content_Type  GAD_7_Severity
# Educational/Tech       Mild              489
#                        Minimal           396
#                        Moderate          357
#                        Severe             61
# Entertainment/Comedy   Mild              498
#                        Minimal           456
#                        Moderate          333
#                        Severe             72
# Gaming                 Mild              457
#                        Minimal           415
#                        Moderate          354
#                        Severe             75
# Lifestyle/Fashion      Mild              513
#                        Moderate          386
#                        Minimal           358
#                        Severe            130
# News/Politics          Minimal           441
#                        Mild              438
#                        Moderate          351
#                        Severe             73
# ...

# %%
df.groupby('Activity_Type')['GAD_7_Severity'].value_counts(ascending = False)
# Out:
# Activity_Type  GAD_7_Severity
# Active         Minimal           2257
#                Mild              2250
#                Moderate          1325
#                Severe             259
# Passive        Moderate           820
#                Mild               641
#                Severe             286
#                Minimal            162
# Name: count, dtype: int64

# %%
df.groupby('Late_Night_Usage')['GAD_7_Severity'].value_counts(ascending = False)
# Out:
# Late_Night_Usage  GAD_7_Severity
# 0                 Minimal           2368
#                   Mild              2073
#                   Moderate           489
#                   Severe              35
# 1                 Moderate          1656
#                   Mild               818
#                   Severe             510
#                   Minimal             51
# Name: count, dtype: int64

# %%
df.groupby('Late_Night_Usage')['PHQ_9_Severity'].value_counts(ascending = False)
# Out:
# Late_Night_Usage  PHQ_9_Severity
# 0                 None-Minimal         3586
#                   Mild                 1183
#                   Moderate              182
#                   Moderately Severe      14
# 1                 Mild                 1177
#                   Moderate             1109
#                   None-Minimal          380
#                   Moderately Severe     342
#                   Severe                 27
# Name: count, dtype: int64

# %%
df.groupby('Activity_Type')['PHQ_9_Severity'].value_counts(ascending = False)
# Out:
# Activity_Type  PHQ_9_Severity
# Active         None-Minimal         3266
#                Mild                 1663
#                Moderate              892
#                Moderately Severe     248
#                Severe                 22
# Passive        None-Minimal          700
#                Mild                  697
#                Moderate              399
#                Moderately Severe     108
#                Severe                  5
# Name: count, dtype: int64

# %%
#Check missing value
check_missing = df.isnull().sum() * 100 / df.shape[0]
check_missing[check_missing > 0].sort_values(ascending=False)
# Out:
# Series([], dtype: float64)

# %%
cat_var = ['User_Archetype' , 'Primary_Platform' , 'Gender' , 'Dominant_Content_Type',  'Activity_Type' , 'Late_Night_Usage',
           'GAD_7_Severity','PHQ_9_Severity', 'Social_Comparison_Trigger']
for i in cat_var: 
    print(f"{i}: {df[i].unique()}")
# Out:
# User_Archetype: ['Hyper-Connected' 'Digital Minimalist' 'Passive Scroller' 'Average User']
# Primary_Platform: ['Twitter/X' 'TikTok' 'Snapchat' 'LinkedIn' 'YouTube' 'Facebook'
#  'Instagram']
# Gender: ['Male' 'Female']
# Dominant_Content_Type: ['Gaming' 'Entertainment/Comedy' 'Lifestyle/Fashion' 'Educational/Tech'
#  'Self-Help/Motivation' 'News/Politics']
# Activity_Type: ['Active' 'Passive']
# Late_Night_Usage: [0 1]
# GAD_7_Severity: ['Mild' 'Minimal' 'Moderate' 'Severe']
# PHQ_9_Severity: ['Mild' 'None-Minimal' 'Moderate' 'Moderately Severe' 'Severe']
# Social_Comparison_Trigger: [0 1]

# %%
#Exploratory Data Analysis

import warnings
warnings.filterwarnings("ignore")
# get list of categorical variables
cat_vars = ['User_Archetype' , 'Primary_Platform' , 'Gender' , 'Dominant_Content_Type',  'Activity_Type' , 'Late_Night_Usage'
            , 'Social_Comparison_Trigger']

# create figure with subplots
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(15, 15))
axs = axs.flatten()

# create histplot for each categorical variable
for i, var in enumerate(cat_vars):
    sns.histplot(x=var, hue='GAD_7_Severity', data=df, ax=axs[i], multiple="fill", kde=False, element="bars", fill=True, stat='density')
    axs[i].set_xticklabels(df[var].unique(), rotation=90)
    axs[i].set_xlabel(var)

# adjust spacing between subplots
fig.tight_layout()

# show plot
plt.show()

# %%
#Exploratory Data Analysis

import warnings
warnings.filterwarnings("ignore")
# get list of categorical variables
cat_vars = ['User_Archetype' , 'Primary_Platform' , 'Gender' , 'Dominant_Content_Type',  'Activity_Type' , 'Late_Night_Usage'
            , 'Social_Comparison_Trigger']

# create figure with subplots
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(15, 15))
axs = axs.flatten()

# create histplot for each categorical variable
for i, var in enumerate(cat_vars):
    sns.histplot(x=var, hue='PHQ_9_Severity', data=df, ax=axs[i], multiple="fill", kde=False, element="bars", fill=True, stat='density')
    axs[i].set_xticklabels(df[var].unique(), rotation=90)
    axs[i].set_xlabel(var)

# adjust spacing between subplots
fig.tight_layout()

# show plot
plt.show()
